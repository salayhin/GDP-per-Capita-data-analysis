# %% [markdown]
# ## Data Collection manually

# %% [markdown]
# Here is Step by step instruction for collecting those data:
#
# 1. Go to this link: http://databank.worldbank.org/data/reports.aspx?source=2&series=NY.GDP.PCAP.CD&country=
# 2. You will find few filter options in the left side. Please make sure you have all countries selected. And from Time filter select all the years.
# 3. Then you will get a pop up with Apply Changes option.
# 4. After all done click to the download CSV option to download the csv file.
# 5. You will find a zip file with two CSV (something like _Data.csv and _Definition and Source.csv) inside
# 6. Copy the _Data.csv file and rename it to gdp.csv to data/* folder

# %% [markdown]
# ## Run Scrapy to import country codes in ISO ALpha 2

# %%
# !cd countrycode && scrapy crawl codes -o ../data/country_codes.csv
# Out:
# 2018-03-25 11:55:10 [scrapy.utils.log] INFO: Scrapy 1.5.0 started (bot: countrycode)
# 2018-03-25 11:55:10 [scrapy.utils.log] INFO: Versions: lxml 4.2.1.0, libxml2 2.9.8, cssselect 1.0.3, parsel 1.4.0, w3lib 1.19.0, Twisted 17.9.0, Python 3.6.3 (default, Oct  3 2017, 21:45:48) - [GCC 7.2.0], pyOpenSSL 17.5.0 (OpenSSL 1.1.0g  2 Nov 2017), cryptography 2.2.1, Platform Linux-4.13.0-37-generic-x86_64-with-Ubuntu-17.10-artful
# 2018-03-25 11:55:10 [scrapy.crawler] INFO: Overridden settings: {'BOT_NAME': 'countrycode', 'EDITOR': 'mvim', 'FEED_FORMAT': 'csv', 'FEED_URI': '../data/country_codes.csv', 'NEWSPIDER_MODULE': 'countrycode.spiders', 'ROBOTSTXT_OBEY': True, 'SPIDER_MODULES': ['countrycode.spiders']}
# 2018-03-25 11:55:10 [scrapy.middleware] INFO: Enabled extensions:
# ['scrapy.extensions.corestats.CoreStats',
#  'scrapy.extensions.telnet.TelnetConsole',
#  'scrapy.extensions.memusage.MemoryUsage',
#  'scrapy.extensions.feedexport.FeedExporter',
# ...

# %% [markdown]
# ## Import Libraries

# %%
import pandas as pd

# %% [markdown]
# ## Import Data

# %%
country_codes = pd.read_csv('/projects/upwork/GDP-per-Capita-data-analysis/data/country_codes.csv')
gdp_csv = pd.read_csv('/projects/upwork/GDP-per-Capita-data-analysis/data/gdp.csv')

# %%
csv_data = gdp_csv.drop(['Series Name', 'Series Code'], axis=1)
csv_data['iso_alpha3'] = csv_data['Country Code']
gdp = csv_data.drop('Country Code', axis=1)

# %%
data = pd.merge(country_codes, gdp, on='iso_alpha3', how='left')

# %%
#data[data['iso_alpha3'].isnull()]

# %%
gdp_data = data.drop(['country', 'iso_alpha3'], axis=1)

# %% [markdown]
# ## Write data into CSV

# %%
gdp_data.to_csv('data/output_gdp_data1.csv', sep='\t', encoding='utf-8')
